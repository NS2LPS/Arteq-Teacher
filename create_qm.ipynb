# %%
from IPython.display import display
import QM
# Out:
# 2026-01-25 10:48:46,559 - qm - INFO     - Starting session: b917ac83-9acf-448c-b765-98d58831642b

# %%
import importlib
importlib.reload(QM)
# Out:
# <module 'QM' from '/home/jupyter-teacher/Arteq-Teacher/QM.py'>

# %%
QM.get_config()
# Out:
# {'qubit': {'LO': 3818180000.0, 'IF': 50000000.0},
#  'resonator': {'LO': 5870000000.0, 'IF': 60000000.0}}

# %% [markdown]
# # Load QM

# %%
# Interactive reload and calibrate
loader = QM.QMloader()
# Out:
# ...
# Output()

# %% [markdown]
# # Monitor QM

# %%
# Queue monitoring
monitor = QM.createQueueMonitor()
# Out:
# ...
# IntProgress(value=0, max=60)
# Label(value='')
# HTML(value='')
# Output()

# %% [markdown]
# # Check QM config

# %%
QM.show_config()
# Out:
# <h3>Elements</h3><ul><li><h4>qubit</h4><ul><li>LO: 3818.18 MHz</li>
#                 <li>IF: 50.00 MHz</li><li>Operations: {'cw': 'const_pulse', 'saturation': 'saturation_pulse', 'pi': 'square_pi_pulse', 'pi_half': 'square_pi_half_pulse', 'x90': 'x90_pulse', 'x180': 'x180_pulse', 'y90': 'y90_pulse', 'y180': 'y180_pulse'}</li></ul></li><li><h4>trigger</h4><ul><li>Operations: {'trigger': 'trigger_pulse'}</li></ul></li><li><h4>resonator</h4><ul><li>LO: 5870.00 MHz</li>
# ...
